# %%
## Implement pre-built absenteeism module and model to transfer the data from Jupyter to MySQL Workbench

from absenteeism_module import *

# %%
df= pd.read_csv('Absenteeism_new_data.csv')
df.head(10)
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  22                  27  01/06/2018                     179
# 1  10                   7  04/06/2018                     361
# 2  14                  23  06/06/2018                     155
# 3  17                  25  08/06/2018                     179
# 4  14                  10  08/06/2018                     155
# 5  28                  11  11/06/2018                     225
# 6  16                   7  13/06/2018                     118
# 7  22                  27  13/06/2018                     179
# 8  34                  26  15/06/2018                     118
# 9  34                  10  20/06/2018                     118
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                26   30                  237.656               19          3
# 1                52   28                  237.656               27          1
# ...

# %%
model = absenteeism_model('model','scaler')
# Out:
# C:\Python\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.linear_model.logistic module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Python\lib\site-packages\sklearn\base.py:313: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...

# %%
pip install -U scikit-learn scipy matplotlib --user
# Out:
# ...
#   Using cached scikit_learn-1.0.2-cp39-cp39-win_amd64.whl (7.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model = absenteeism_model('model','scaler')

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %%
## Importing pymysql 
## Creating connection and Cursor and INSERT statement

import pymysql
conn = pymysql.connect(database ='predicted_outputs', user = 'root', password = 'tmdgml159')
cursor = conn.cursor()

# %%
df_new_obs = model.predicted_outputs()
insert_query = 'INSERT INTO predicted_outputs VALUES'

# %%
df_new_obs.shape
# Out:
# (40, 13)

# %%
df_new_obs.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0         0       0.0         0         1            6
# 1         1       0.0         0         0            6
# 2         0       0.0         0         1            6
# 3         0       0.0         0         1            6
# 4         1       0.0         0         0            6
#
#    Transportation Expense  Age  Body Mass Index  Education  Children  Pet  \
# 0                     179   30               19          1         0    0
# 1                     361   28               27          0         1    4
# 2                     155   34               25          0         2    0
# 3                     179   40               22          1         2    0
# 4                     155   34               25          0         2    0
#
#    Probability  Prediction
# 0     0.122799           0
# 1     0.873392           1
# 2     0.268305           0
# 3     0.196385           0
# 4     0.723502           1

# %%
df_new_obs.columns.values
# Out:
# array(['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4', 'Month Value',
#        'Transportation Expense', 'Age', 'Body Mass Index', 'Education',
#        'Children', 'Pet', 'Probability', 'Prediction'], dtype=object)

# %%
df_new_obs[df_new_obs.columns.values[6]][0]
# Out:
# 30

# %%
## Transferring Data using for loop
## first outer loop goes through every row of the dataframe
## inner loop goes through every column 

for i in range (df_new_obs.shape[0]):
    insert_query  +=  '('
    
    for j in range(df_new_obs.shape[1]):
        insert_query += str(df_new_obs[df_new_obs.columns.values[j]][i])+ ', '

    insert_query = insert_query[:-2] + '), '

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8733923470447209, 1), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.26830495460343223, 0), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.1963853143922252, 0), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7235017225544896, 1), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7168905020985188, 1), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.5705238370679658, 1), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.1341180540896835, 0), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5250065611752316, 1), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.4549980207286245, 0), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6447416367376194, 1), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.3511076612078474, 0), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.09653346354354148, 
# ...

# %%
insert_query = insert_query[:-2] +';'

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8733923470447209, 1), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.26830495460343223, 0), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.1963853143922252, 0), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7235017225544896, 1), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7168905020985188, 1), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.5705238370679658, 1), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.1341180540896835, 0), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5250065611752316, 1), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.4549980207286245, 0), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6447416367376194, 1), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.3511076612078474, 0), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12279926243494323, 0), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.09653346354354148, 
# ...

# %%
cursor.execute(insert_query)
# Out:
# 40

# %%
conn.commit()
